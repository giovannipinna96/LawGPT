# %% [markdown]
# # da abbandonare perchè è da fare in locale dato che qua non cè chrome
# ### Test for scraping Cassazione web site

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests

# %%
username = "units"
password = "Italgiure2022"

# %%
import requests
from bs4 import BeautifulSoup

# Define your login credentials
url = f"https://{username}:{password}@www.italgiure.giustizia.it/xway/application/nif/isapi/hc.dll?db=civile&lang=it"

# Send a GET request with the credentials embedded in the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")

    # Process and extract the required information
    # ...

else:
    print("Failed to fetch the page")
# Out:
# Failed to fetch the page

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="it">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Centro Elettronico di Documentazione - Corte Suprema di Cassazione" name="Author"/>
# <meta content="italgiure, italgiureweb, nif, giustizia, legge, giurisprudenza, normativa, corte di cassazione, sentenze, massime, magistrati, magistratura" name="keywords"/>
# <meta content="Sito del Centro Elettronico di Documentazione della Corte Suprema di Cassazione" name="description"/>
# <title>ItalgiureWeb - Corte di Cassazione</title>
# <link href="css/home.css" rel="stylesheet" type="text/css"/>
# <!-- Modifica del 27 ago 2013 cega 719 -->
# <script src="redirection-mobile1.js"></script>
# <script src="testMobile.js"></script>
# <script src="page_logic/label_legrecente_2013.js">
# //
# </script>
# <script src="page_logic/home_page2.js">
# //
# </script>
# <link href="immagini/iweb.ico" rel="shortcut icon" type="image/icon"/>
# <style type="text/css">
# ...
